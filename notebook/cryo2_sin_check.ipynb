# %% [markdown]
# #### Cryosat Level-1b SARIn data visualization.

# %%
import numpy as np
import netCDF4 as nc
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import rasterio as rio

# %%
## cryosat-2 sarin data.
path_cryo2_sin_l1b = 'data/cryosat-2/CS_OFFL_SIR_SIN_1B_20221105T233231_20221105T233436_E001.nc'  # GOPM:LRM-GOP
## remote sensing data
path_rsimg = 'data/rsimg/chenghai_20200827_wgs84.tif'

# %% [markdown]
# ### Data reading

# %%
## 1. cryosat-2 SARIn data
cryo2_sin_l1b = nc.Dataset(path_cryo2_sin_l1b)
## 2. remote sensing image
rsimg_rio = rio.open(path_rsimg)

# %%
cryo2_sin_l1b
# Out:
# <class 'netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     product_name: CS_OFFL_SIR_SIN_1B_20221105T233231_20221105T233436_E001
#     processing_stage: OFFL
#     reference_document: CS-RS-ACS-ESL-5364 2.0
#     doi: 10.5270/CR2-6afef01
#     acquisition_station: Kiruna
#     mission: Cryosat
#     processing_centre: PDS
#     creation_time: UTC=2022-12-03T08:43:35
#     sensing_start: 05-NOV-2022 23:32:31.276948
#     sensing_stop: 05-NOV-2022 23:34:35.744725
#     software_version: SARIN/7.1
#     phase: 4
#     cycle_number: 28
#     rel_orbit_number: 3783
#     abs_orbit_number: 66673
#     state_vector_time: UTC=2022-11-05T23:33:33.356302
#     delta_ut1: -0.013349000364542007
#     x_position: -1178579.125
#     y_position: 6068776.5
#     z_position: 3476113.25
#     x_velocity: 38.18757247924805
#     y_velocity: 3760.29052734375
#     z_velocity: -6526.154296875
#     vector_source: doris_precise
#     leap_utc:
#     leap_sign: 0
#     leap_err: 0
#     product_err: 0
#     first_record_time: TAI=2022-11-05T23:33:08.276948
#     last_record_time: TAI=2022-11-05T23:35:12.435655
#     abs_orbit_start: 66673
#     rel_time_acs_node_start: 2423.980712890625
#     abs_orbit_stop: 66673
#     rel_time_acs_node_stop: 2548.139404296875
#     equator_cross_time: UTC=2022-11-05T22:52:07.368826
#     equator_cross_long: -69768350
#     ascending_flag: D
#     first_record_lat: 33265128
#     first_record_lon: 101431249
#     last_record_lat: 25724998
#     last_record_lon: 100562235
#     l0_proc_flag: 0
#     l0_processing_quality: 10000
#     l0_proc_thresh: 500
#     l0_gaps_flag: 0
#     l0_gaps_num: 0
#     instr_id: A
#     sir_op_mode: SARIN
#     sir_configuration: BOTH
#     open_ocean_percent: 0
#     close_sea_percent: 282
#     continent_ice_percent: 0
#     land_percent: 9718
#     l1b_prod_status: 0
#     l1b_proc_flag: 0
#     l1b_processing_quality: 10000
#     l1b_proc_thresh: 500
#     xref_mog2d: CS_OPER_AUX_MOG_2D_20221105T180000_20221105T180000_0001.DBL,CS_OPER_AUX_MOG_2D_20221106T000000_20221106T000000_0001.DBL
#     xref_cal1: CS_OFFL_SIR_SIC11B_20221105T145040_20221105T145043_E001.DBL
#     xref_cal2: CS_OFFL_SIR1SIC21B_20221107T111807_20221107T112044_E001.DBL,CS_OFFL_SIR2SIC21B_20221107T111807_20221107T112733_E001.DBL
#     xref_constants: Geophysical_Constants_5.0.xml
#     xref_uso: CS_OPER_AUX_DORUSO_20100411T040029_20221202T053446_0001.DBL
#     xref_earth_tide: CS_OPER_AUX_CARTWR_00000000T000000_99999999T999999_0002.DBL
#     xref_gim: CS_OPER_AUX_IONGIM_20221105T000000_20221105T235959_0001.DBL
#     xref_iono_cor: CS_OPER_AUX_MICOEF_00000000T000000_99999999T999999_0002.DBL
#     xref_siral_characterisation: CS_OPER_AUX_IPFDBA_20100701T000000_99999999T999999_0003.EEF
#     xref_mean_pressure: CS_OPER_AUX_SEAMPS_20221105T180000_20221105T180000_0001.DBL,CS_OPER_AUX_SEAMPS_20221106T000000_20221106T000000_0001.DBL
#     xref_meteo: CS_OPER_AUX_ALTGRD_20110504T100000_20301231T235959_0003.DBL
#     xref_dip_map: CS_OPER_AUX_DIPMAP_00000000T000000_99999999T999999_0002.DBL
#     xref_ocean_tide: CS_OPER_AUX_OCTIDE_00000000T000000_99999999T999999_0003.DBL
#     xref_orbit: CS_OPER_MPL_ORBPRE_20221105T001000_20221205T001000_0001.EEF,CS_OPER_AUX_ORBDOR_20221104T215523_20221106T002323_F001.EEF
#     xref_pole_location: CS_OPER_AUX_POLLOC_19870101T000000_20231201T000000_0002.DBL
#     xref_pconf: CS_OPER_PCONF_IPF1_20161001T000000_99999999T000000_0001.XML
#     xref_s1s2_pressure_00h: CS_OPER_AUX_PRSS00_00000000T000000_99999999T999999_0001.DBL
#     xref_s1s2_pressure_06h: CS_OPER_AUX_PRSS06_00000000T000000_99999999T999999_0001.DBL
#     xref_s1s2_pressure_12h: CS_OPER_AUX_PRSS12_00000000T000000_99999999T999999_0001.DBL
#     xref_s1s2_pressure_18h: CS_OPER_AUX_PRSS18_00000000T000000_99999999T999999_0001.DBL
#     xref_s1_tide_amplitude: CS_OPER_AUX_S1AMPL_00000000T000000_99999999T999999_0001.DBL
#     xref_s1_tide_phase: CS_OPER_AUX_S1PHAS_00000000T000000_99999999T999999_0001.DBL
#     xref_s2_tide_amplitude: CS_OPER_AUX_S2AMPL_00000000T000000_99999999T999999_0001.DBL
#     xref_s2_tide_phase: CS_OPER_AUX_S2PHAS_00000000T000000_99999999T999999_0001.DBL
#     xref_sai: CS_OPER_AUX_SUNACT_19910101T000000_20231201T000000_0001.DBL
#     xref_orbit_scenario: CS_OPER_MPL_ORBREF_20220704T000103_20231224T225544_0001.EEF
#     xref_siral_l0: CS_OPER_SIR2SIN_0__20221105T233231_20221105T233417_0001.DBL,CS_OPER_SIR1SIN_0__20221105T233231_20221105T233436_0001.DBL,CS_OPER_SIR2SIN_0__20221105T233417_20221105T233436_0001.DBL,CS_OPER_SIR1TKSI0__20221105T233231_20221105T233436_0001.DBL
#     xref_cal1_sarin: CS_OFFL_SIR_SICC1B_20221106T043225_20221106T043337_E001.DBL
#     xref_star_tracker_attref: CS_OFFL_STR_ATTREF_20221105T215523_20221107T002322_E001.EEF
#     xref_surf_pressure: CS_OPER_AUX_SURFPS_20221105T180000_20221105T180000_0001.DBL,CS_OPER_AUX_SURFPS_20221106T000000_20221106T000000_0001.DBL
#     xref_surf_type: CS_OPER_AUX_LS_MAP_00000000T000000_99999999T999999_0002.DBL
#     xref_tidal_load: CS_OPER_AUX_TDLOAD_00000000T000000_99999999T999999_0003.DBL
#     xref_u_wind: CS_OPER_AUX_U_WIND_20221105T180000_20221105T180000_0001.DBL,CS_OPER_AUX_U_WIND_20221106T000000_20221106T000000_0001.DBL
#     xref_v_wind: CS_OPER_AUX_V_WIND_20221105T180000_20221105T180000_0001.DBL,CS_OPER_AUX_V_WIND_20221106T000000_20221106T000000_0001.DBL
#     xref_wet_trop: CS_OPER_AUX_WETTRP_20221105T180000_20221105T180000_0001.DBL,CS_OPER_AUX_WETTRP_20221106T000000_20221106T000000_0001.DBL
#     dimensions(sizes): time_cor_01(142), nlooks_ku(60), ns_20_ku(1024), ns_plrm_01_ku(512), ns_plrm_20_ku(512), space_3d(3), time_20_ku(2827), time_plrm_01_ku(140), time_plrm_20_ku(2441)
#     variables(dimensions): int32 agc_ch1_20_ku(time_20_ku), int32 agc_ch2_20_ku(time_20_ku), int32 alt_20_ku(time_20_ku), int32 alt_plrm_01_ku(time_plrm_01_ku), int32 alt_plrm_20_ku(time_plrm_20_ku), int32 beam_dir_vec_20_ku(time_20_ku, space_3d), int16 coherence_waveform_20_ku(time_20_ku, ns_20_ku), int32 cor2_applied_20_ku(time_20_ku), int32 dop_angle_start_20_ku(time_20_ku), int32 dop_angle_stop_20_ku(time_20_ku), int32 dop_cor_20_ku(time_20_ku), int16 echo_numval_20_ku(time_20_ku), int16 echo_numval_plrm_01_ku(time_plrm_01_ku), int16 echo_numval_plrm_20_ku(time_plrm_20_ku), int32 echo_scale_factor_20_ku(time_20_ku), int32 echo_scale_factor_plrm_01_ku(time_plrm_01_ku), int32 echo_scale_factor_plrm_20_ku(time_plrm_20_ku), int32 echo_scale_pwr_20_ku(time_20_ku), int32 echo_scale_pwr_plrm_01_ku(time_plrm_01_ku), int32 echo_scale_pwr_plrm_20_ku(time_plrm_20_ku), int16 flag_echo_20_ku(time_20_ku), int16 flag_echo_plrm_01_ku(time_plrm_01_ku), int16 flag_echo_plrm_20_ku(time_plrm_20_ku), int8 flag_instr_conf_rx_bwdt_20_ku(time_20_ku), int8 flag_instr_conf_rx_flags_20_ku(time_20_ku), int8 flag_instr_conf_rx_in_use_20_ku(time_20_ku), int8 flag_instr_conf_rx_str_in_use_20_ku(time_20_ku), int8 flag_instr_conf_rx_trk_mode_20_ku(time_20_ku), int8 flag_instr_mode_att_ctrl_20_ku(time_20_ku), int8 flag_instr_mode_flags_20_ku(time_20_ku), int8 flag_instr_mode_op_20_ku(time_20_ku), int32 flag_mcd_20_ku(time_20_ku), int16 flag_trk_cycle_20_ku(time_20_ku), int32 h0_applied_20_ku(time_20_ku), int32 h0_fai_word_20_ku(time_20_ku), int32 h0_lai_word_20_ku(time_20_ku), int32 instr_cor_gain_rx_20_ku(time_20_ku), int32 instr_cor_gain_tx_rx_20_ku(time_20_ku), int32 instr_cor_range_rx_20_ku(time_20_ku), int32 instr_cor_range_tx_rx_20_ku(time_20_ku), int32 instr_ext_ph_cor_20_ku(time_20_ku), int32 instr_int_ph_cor_20_ku(time_20_ku), int32 inter_base_vec_20_ku(time_20_ku, space_3d), int32 lat_20_ku(time_20_ku), int32 lat_plrm_01_ku(time_plrm_01_ku), int32 lat_plrm_20_ku(time_plrm_20_ku), int32 lon_20_ku(time_20_ku), int32 lon_plrm_01_ku(time_plrm_01_ku), int32 lon_plrm_20_ku(time_plrm_20_ku), int32 look_angle_start_20_ku(time_20_ku), int32 look_angle_stop_20_ku(time_20_ku), int32 noise_power_20_ku(time_20_ku), int32 off_nadir_pitch_angle_str_20_ku(time_20_ku), int32 off_nadir_roll_angle_str_20_ku(time_20_ku), int32 off_nadir_yaw_angle_str_20_ku(time_20_ku), int32 orb_alt_rate_20_ku(time_20_ku), int32 ph_diff_waveform_20_ku(time_20_ku, ns_20_ku), int32 ph_slope_cor_20_ku(time_20_ku), uint16 pwr_waveform_20_ku(time_20_ku, ns_20_ku), uint16 pwr_waveform_plrm_01_ku(time_plrm_01_ku, ns_plrm_01_ku), uint16 pwr_waveform_plrm_20_ku(time_plrm_20_ku, ns_plrm_20_ku), int32 rec_count_20_ku(time_20_ku), int32 sat_vel_vec_20_ku(time_20_ku, space_3d), int16 seq_count_20_ku(time_20_ku), int16 stack_centre_20_ku(time_20_ku), int16 stack_centre_angle_20_ku(time_20_ku), int16 stack_centre_look_angle_20_ku(time_20_ku), int16 stack_gaussian_fitting_residuals_20_ku(time_20_ku), int16 stack_kurtosis_20_ku(time_20_ku), int16 stack_mask_start_stop_20_ku(time_20_ku, nlooks_ku), int16 stack_number_after_weighting_20_ku(time_20_ku), int16 stack_number_before_weighting_20_ku(time_20_ku), int16 stack_peakiness_20_ku(time_20_ku), int16 stack_scaled_amplitude_20_ku(time_20_ku), int16 stack_skewness_20_ku(time_20_ku), int16 stack_std_20_ku(time_20_ku), int16 stack_std_angle_20_ku(time_20_ku), float64 time_20_ku(time_20_ku), float64 time_plrm_01_ku(time_plrm_01_ku), float64 time_plrm_20_ku(time_plrm_20_ku), int32 tot_gain_ch1_20_ku(time_20_ku), int32 tot_gain_ch2_20_ku(time_20_ku), int32 transmit_pwr_20_ku(time_20_ku), int32 uso_cor_20_ku(time_20_ku), int32 uso_cor_plrm_01_ku(time_plrm_01_ku), int32 uso_cor_plrm_20_ku(time_plrm_20_ku), int64 window_del_20_ku(time_20_ku), int64 window_del_plrm_01_ku(time_plrm_01_ku), int64 window_del_plrm_20_ku(time_plrm_20_ku), float64 time_cor_01(time_cor_01), int32 lat_cor_01(time_cor_01), int32 lon_cor_01(time_cor_01), int32 mod_dry_tropo_cor_01(time_ ...
#     groups:

# %%
print('Cryosat-1 l1b data:')
for i in range(len(cryo2_sin_l1b.variables.keys())):
    print(list(cryo2_sin_l1b.variables.keys())[i])
# Out:
# Cryosat-1 l1b data:
# agc_ch1_20_ku
# agc_ch2_20_ku
# alt_20_ku
# alt_plrm_01_ku
# alt_plrm_20_ku
# beam_dir_vec_20_ku
# coherence_waveform_20_ku
# cor2_applied_20_ku
# dop_angle_start_20_ku
# dop_angle_stop_20_ku
# dop_cor_20_ku
# echo_numval_20_ku
# echo_numval_plrm_01_ku
# echo_numval_plrm_20_ku
# echo_scale_factor_20_ku
# echo_scale_factor_plrm_01_ku
# echo_scale_factor_plrm_20_ku
# echo_scale_pwr_20_ku
# echo_scale_pwr_plrm_01_ku
# echo_scale_pwr_plrm_20_ku
# flag_echo_20_ku
# flag_echo_plrm_01_ku
# flag_echo_plrm_20_ku
# flag_instr_conf_rx_bwdt_20_ku
# flag_instr_conf_rx_flags_20_ku
# flag_instr_conf_rx_in_use_20_ku
# flag_instr_conf_rx_str_in_use_20_ku
# flag_instr_conf_rx_trk_mode_20_ku
# flag_instr_mode_att_ctrl_20_ku
# flag_instr_mode_flags_20_ku
# flag_instr_mode_op_20_ku
# flag_mcd_20_ku
# flag_trk_cycle_20_ku
# h0_applied_20_ku
# h0_fai_word_20_ku
# h0_lai_word_20_ku
# instr_cor_gain_rx_20_ku
# instr_cor_gain_tx_rx_20_ku
# instr_cor_range_rx_20_ku
# instr_cor_range_tx_rx_20_ku
# instr_ext_ph_cor_20_ku
# instr_int_ph_cor_20_ku
# inter_base_vec_20_ku
# lat_20_ku
# lat_plrm_01_ku
# lat_plrm_20_ku
# lon_20_ku
# lon_plrm_01_ku
# lon_plrm_20_ku
# look_angle_start_20_ku
# look_angle_stop_20_ku
# noise_power_20_ku
# off_nadir_pitch_angle_str_20_ku
# off_nadir_roll_angle_str_20_ku
# off_nadir_yaw_angle_str_20_ku
# orb_alt_rate_20_ku
# ph_diff_waveform_20_ku
# ph_slope_cor_20_ku
# pwr_waveform_20_ku
# pwr_waveform_plrm_01_ku
# pwr_waveform_plrm_20_ku
# rec_count_20_ku
# sat_vel_vec_20_ku
# seq_count_20_ku
# stack_centre_20_ku
# stack_centre_angle_20_ku
# stack_centre_look_angle_20_ku
# stack_gaussian_fitting_residuals_20_ku
# stack_kurtosis_20_ku
# stack_mask_start_stop_20_ku
# stack_number_after_weighting_20_ku
# stack_number_before_weighting_20_ku
# stack_peakiness_20_ku
# stack_scaled_amplitude_20_ku
# stack_skewness_20_ku
# stack_std_20_ku
# stack_std_angle_20_ku
# time_20_ku
# time_plrm_01_ku
# time_plrm_20_ku
# tot_gain_ch1_20_ku
# tot_gain_ch2_20_ku
# transmit_pwr_20_ku
# uso_cor_20_ku
# uso_cor_plrm_01_ku
# uso_cor_plrm_20_ku
# window_del_20_ku
# window_del_plrm_01_ku
# window_del_plrm_20_ku
# time_cor_01
# lat_cor_01
# lon_cor_01
# mod_dry_tropo_cor_01
# mod_wet_tropo_cor_01
# inv_bar_cor_01
# hf_fluct_total_cor_01
# iono_cor_gim_01
# iono_cor_01
# ocean_tide_01
# ocean_tide_eq_01
# load_tide_01
# solid_earth_tide_01
# pole_tide_01
# surf_type_01
# flag_cor_status_01
# flag_cor_err_01
# ind_first_meas_20hz_01
# ind_meas_1hz_20_ku

# %%
lon_20_ku_l1b = cryo2_sin_l1b['lon_20_ku'][:]
lat_20_ku_l1b = cryo2_sin_l1b['lat_20_ku'][:]
time_20_ku_l1b = cryo2_sin_l1b['time_20_ku'][:]
waveform_l1b = cryo2_sin_l1b['pwr_waveform_20_ku'][:]
print(time_20_ku_l1b.shape)
print(waveform_l1b.shape)  ## waveform
# Out:
# (2827,)
# (2827, 1024)

# %%
# print('Cryosat-2 l2 data:')
# for i in range(len(cryo2_l2.variables.keys())):
#     print(list(cryo2_l2.variables.keys())[i])

# %%
# lon_20_ku_l2 = cryo2_l2['lon_20_ku'][:]
# lat_20_ku_l2 = cryo2_l2['lat_20_ku'][:]
# time_20_ku_l2 = cryo2_l2['time_20_ku'][:]
# time_20_ku_dyr_l2 = second_to_dyr(time_20_ku_l2)
# print(time_20_ku_l2.shape)  ##

# %% [markdown]
# ### Visualization from global perspective

# %%
proj = ccrs.PlateCarree(central_longitude=0.0)
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection=proj)
ax.stock_img()
orbit = 'cycle_'+str(cryo2_sin_l1b.cycle_number)+'-pass_'+str(cryo2_sin_l1b.rel_orbit_number)
ax.plot(cryo2_sin_l1b['lon_20_ku'][:], cryo2_sin_l1b['lat_20_ku'][:], marker='.', markersize=1, 
                                                        linewidth=0.0, label=orbit, color='red')
ax.gridlines(linewidth=1, color='gray', linestyle='--')
ax.legend()

# %% [markdown]
# ### Visualization from local perspective

# %%
rsimg_color = rsimg_rio.read()[0:3,:,:].transpose(1,2,0)[:,:,::-1]
rsimg_color = (rsimg_color - 0) / (1500)

# %%
ids = np.where((lat_20_ku_l1b[:]>26.45) & (lat_20_ku_l1b[:]<26.65))[0]  
id = ids[34]
fig, ax = plt.subplots(1,2,figsize=(9,4))
ax[0].imshow(rsimg_color, extent=(rsimg_rio.bounds.left, 
                                rsimg_rio.bounds.right, 
                                rsimg_rio.bounds.bottom, 
                                rsimg_rio.bounds.top))
ax[0].scatter(x=lon_20_ku_l1b[ids], y=lat_20_ku_l1b[ids], s=0.5, color='green')  ## altimetry data
ax[0].scatter(x=lon_20_ku_l1b[id], y=lat_20_ku_l1b[id], s=1.5, color='red')  ## altimetry data
ax[1].plot(waveform_l1b[id], color='red')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..4.4093333333333335].
