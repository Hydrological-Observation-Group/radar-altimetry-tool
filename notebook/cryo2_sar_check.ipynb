# %% [markdown]
# #### Cryosat Level-1b SAR data visualization.

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np
import rasterio as rio 
import xarray as xr

# %%
## cryosat-2 sar data.
path_cryo2_sar_l1b = 'data/cryosat-2/CS_OFFL_SIR_SAR_1B_20230302T173617_20230302T174047_E001.nc' 
## remote sensing data
path_rsimg = 'data/rsimg/ubolratana_20210620_wgs84.tif'

# %% [markdown]
# ### Data reading

# %%
## 1. cryosat-2 SAR data
cryo2_sar_l1b = xr.open_dataset(path_cryo2_sar_l1b)
## 2. remote sensing image
rsimg_rio = rio.open(path_rsimg)

# %%
cryo2_sar_l1b
# Out:
# <xarray.Dataset>
# Dimensions:                                 (time_20_ku: 6031,
#                                              time_plrm_01_ku: 300,
#                                              time_plrm_20_ku: 5182,
#                                              space_3d: 3, ns_20_ku: 256,
#                                              ns_plrm_01_ku: 128,
#                                              ns_plrm_20_ku: 128,
#                                              nlooks_ku: 205, time_cor_01: 302)
# Coordinates:
#     lat_20_ku                               (time_20_ku) float64 ...
#     lat_plrm_01_ku                          (time_plrm_01_ku) float64 ...
#     lat_plrm_20_ku                          (time_plrm_20_ku) float64 ...
#     lon_20_ku                               (time_20_ku) float64 ...
#     lon_plrm_01_ku                          (time_plrm_01_ku) float64 ...
#     lon_plrm_20_ku                          (time_plrm_20_ku) float64 ...
#   * time_20_ku                              (time_20_ku) datetime64[ns] 2023-...
#   * time_plrm_01_ku                         (time_plrm_01_ku) datetime64[ns] ...
#   * time_plrm_20_ku                         (time_plrm_20_ku) datetime64[ns] ...
#   * time_cor_01                             (time_cor_01) datetime64[ns] 2023...
#     lat_cor_01                              (time_cor_01) float64 ...
#     lon_cor_01                              (time_cor_01) float64 ...
# Dimensions without coordinates: space_3d, ns_20_ku, ns_plrm_01_ku,
#                                 ns_plrm_20_ku, nlooks_ku
# Data variables: (12/96)
#     agc_ch1_20_ku                           (time_20_ku) float64 ...
#     agc_ch2_20_ku                           (time_20_ku) float64 ...
#     alt_20_ku                               (time_20_ku) float64 ...
#     alt_plrm_01_ku                          (time_plrm_01_ku) float64 ...
#     alt_plrm_20_ku                          (time_plrm_20_ku) float64 ...
#     beam_dir_vec_20_ku                      (time_20_ku, space_3d) float64 ...
#     ...                                      ...
#     flag_cor_status_01                      (time_cor_01) float64 ...
#     flag_cor_err_01                         (time_cor_01) float64 ...
#     ind_first_meas_20hz_01                  (time_cor_01) float64 ...
#     ind_meas_1hz_20_ku                      (time_20_ku) float32 ...
#     coherence_waveform_20_ku                (time_20_ku, ns_20_ku) float32 ...
#     ph_diff_waveform_20_ku                  (time_20_ku, ns_20_ku) float64 ...
# Attributes: (12/92)
#     product_name:                 CS_OFFL_SIR_SAR_1B_20230302T173617_20230302...
#     processing_stage:             OFFL
#     reference_document:           CS-RS-ACS-ESL-5364 2.0
#     doi:                          10.5270/CR2-fbae3cd
#     acquisition_station:          Kiruna
#     mission:                      Cryosat
#     ...                           ...
#     xref_surf_pressure:           CS_OPER_AUX_SURFPS_20230302T120000_20230302...
#     xref_surf_type:               CS_OPER_AUX_LS_MAP_00000000T000000_99999999...
#     xref_tidal_load:              CS_OPER_AUX_TDLOAD_00000000T000000_99999999...
#     xref_u_wind:                  CS_OPER_AUX_U_WIND_20230302T120000_20230302...
#     xref_v_wind:                  CS_OPER_AUX_V_WIND_20230302T120000_20230302...
#     xref_wet_trop:                CS_OPER_AUX_WETTRP_20230302T120000_20230302...

# %%
print('Cryosat-1 l1b data:')
for i in range(len(cryo2_sar_l1b.variables.keys())):
    print(list(cryo2_sar_l1b.variables.keys())[i])
# Out:
# Cryosat-1 l1b data:
# agc_ch1_20_ku
# agc_ch2_20_ku
# alt_20_ku
# alt_plrm_01_ku
# alt_plrm_20_ku
# beam_dir_vec_20_ku
# cor2_applied_20_ku
# dop_angle_start_20_ku
# dop_angle_stop_20_ku
# dop_cor_20_ku
# echo_numval_20_ku
# echo_numval_plrm_01_ku
# echo_numval_plrm_20_ku
# echo_scale_factor_20_ku
# echo_scale_factor_plrm_01_ku
# echo_scale_factor_plrm_20_ku
# echo_scale_pwr_20_ku
# echo_scale_pwr_plrm_01_ku
# echo_scale_pwr_plrm_20_ku
# flag_echo_20_ku
# flag_echo_plrm_01_ku
# flag_echo_plrm_20_ku
# flag_instr_conf_rx_bwdt_20_ku
# flag_instr_conf_rx_flags_20_ku
# flag_instr_conf_rx_in_use_20_ku
# flag_instr_conf_rx_str_in_use_20_ku
# flag_instr_conf_rx_trk_mode_20_ku
# flag_instr_mode_att_ctrl_20_ku
# flag_instr_mode_flags_20_ku
# flag_instr_mode_op_20_ku
# flag_mcd_20_ku
# flag_trk_cycle_20_ku
# h0_applied_20_ku
# h0_fai_word_20_ku
# h0_lai_word_20_ku
# instr_cor_gain_rx_20_ku
# instr_cor_gain_tx_rx_20_ku
# instr_cor_range_rx_20_ku
# instr_cor_range_tx_rx_20_ku
# instr_ext_ph_cor_20_ku
# instr_int_ph_cor_20_ku
# inter_base_vec_20_ku
# lat_20_ku
# lat_plrm_01_ku
# lat_plrm_20_ku
# lon_20_ku
# lon_plrm_01_ku
# lon_plrm_20_ku
# look_angle_start_20_ku
# look_angle_stop_20_ku
# noise_power_20_ku
# off_nadir_pitch_angle_str_20_ku
# off_nadir_roll_angle_str_20_ku
# off_nadir_yaw_angle_str_20_ku
# orb_alt_rate_20_ku
# ph_slope_cor_20_ku
# pwr_waveform_20_ku
# pwr_waveform_plrm_01_ku
# pwr_waveform_plrm_20_ku
# rec_count_20_ku
# sat_vel_vec_20_ku
# seq_count_20_ku
# stack_centre_20_ku
# stack_centre_angle_20_ku
# stack_centre_look_angle_20_ku
# stack_gaussian_fitting_residuals_20_ku
# stack_kurtosis_20_ku
# stack_mask_start_stop_20_ku
# stack_number_after_weighting_20_ku
# stack_number_before_weighting_20_ku
# stack_peakiness_20_ku
# stack_scaled_amplitude_20_ku
# stack_skewness_20_ku
# stack_std_20_ku
# stack_std_angle_20_ku
# time_20_ku
# time_plrm_01_ku
# time_plrm_20_ku
# tot_gain_ch1_20_ku
# tot_gain_ch2_20_ku
# transmit_pwr_20_ku
# uso_cor_20_ku
# uso_cor_plrm_01_ku
# uso_cor_plrm_20_ku
# window_del_20_ku
# window_del_plrm_01_ku
# window_del_plrm_20_ku
# time_cor_01
# lat_cor_01
# lon_cor_01
# mod_dry_tropo_cor_01
# mod_wet_tropo_cor_01
# inv_bar_cor_01
# hf_fluct_total_cor_01
# iono_cor_gim_01
# iono_cor_01
# ocean_tide_01
# ocean_tide_eq_01
# load_tide_01
# solid_earth_tide_01
# pole_tide_01
# surf_type_01
# flag_cor_status_01
# flag_cor_err_01
# ind_first_meas_20hz_01
# ind_meas_1hz_20_ku
# coherence_waveform_20_ku
# ph_diff_waveform_20_ku

# %%
lon_20_ku_l1b = cryo2_sar_l1b['lon_20_ku'][:]
lat_20_ku_l1b = cryo2_sar_l1b['lat_20_ku'][:]
time_20_ku_l1b = cryo2_sar_l1b['time_20_ku'][:]
waveform_l1b = cryo2_sar_l1b['pwr_waveform_20_ku'][:]
print(time_20_ku_l1b.shape)
print(waveform_l1b.shape)  ## waveform
# Out:
# (6031,)
# (6031, 256)

# %%
# print('Cryosat-2 l2 data:')
# for i in range(len(cryo2_l2.variables.keys())):
#     print(list(cryo2_l2.variables.keys())[i])

# %%
# lon_20_ku_l2 = cryo2_l2['lon_20_ku'][:]
# lat_20_ku_l2 = cryo2_l2['lat_20_ku'][:]
# time_20_ku_l2 = cryo2_l2['time_20_ku'][:]
# time_20_ku_dyr_l2 = second_to_dyr(time_20_ku_l2)
# print(time_20_ku_l2.shape)  ##

# %% [markdown]
# ### Visualization from global perspective

# %%
proj = ccrs.PlateCarree(central_longitude=0.0)
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection=proj)
ax.stock_img()
orbit = 'cycle_'+str(cryo2_sar_l1b.cycle_number)+'-pass_'+str(cryo2_sar_l1b.rel_orbit_number)
ax.plot(cryo2_sar_l1b['lon_20_ku'][:], 
        cryo2_sar_l1b['lat_20_ku'][:], 
        marker='.', markersize=1, 
        linewidth=0.0, label=orbit, color='red')
ax.gridlines(linewidth=1, color='gray', linestyle='--')
ax.legend()

# %% [markdown]
# ### Visualization from local perspective

# %%
rsimg_color = rsimg_rio.read()[0:3,:,:].transpose(1,2,0)[:,:,::-1]
rsimg_color = (rsimg_color - 0) / (2000)

# %%
ids = np.where((lat_20_ku_l1b[:]>16.55) & (lat_20_ku_l1b[:]<16.85))[0]  
id = ids[43]
fig, ax = plt.subplots(1,2,figsize=(9,4))
ax[0].imshow(rsimg_color, extent=(rsimg_rio.bounds.left, 
                                rsimg_rio.bounds.right, 
                                rsimg_rio.bounds.bottom, 
                                rsimg_rio.bounds.top))
ax[0].scatter(x=lon_20_ku_l1b[ids], y=lat_20_ku_l1b[ids], s=0.5, color='green')  ## altimetry data
ax[0].scatter(x=lon_20_ku_l1b[id], y=lat_20_ku_l1b[id], s=1.5, color='red')  ## altimetry data
ax[1].plot(waveform_l1b[id], color='red')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..6.8895].
